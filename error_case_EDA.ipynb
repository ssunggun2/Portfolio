# %% [markdown]
# <a href="https://colab.research.google.com/github/ssunggun2/Portfolio/blob/main/error_case_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import os

# %%
csv_dir = '/content/drive/MyDrive'
csv_name = 'real_error_case.csv'
csv_fPath = os.path.join(csv_dir, csv_name)

# %%
df = pd.read_csv(csv_fPath)

# %%
print(len(df))
# Out:
# 2115

# %%
df.head()
# Out:
#    id error case  ... reason13 Unnamed: 15
# 0  20         5번  ...      NaN         NaN
# 1  23         4번  ...      NaN         NaN
# 2  24         5번  ...      NaN         NaN
# 3  32         1번  ...      NaN         NaN
# 4  36         해결  ...      NaN         NaN
#
# [5 rows x 16 columns]

# %%
len(df)
# Out:
# 2115

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2115 entries, 0 to 2114
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           2115 non-null   int64
#  1   error case   2115 non-null   object
#  2   reason1      1440 non-null   object
#  3   reason2      72 non-null     object
#  4   reason3      8 non-null      object
#  5   reason4      2 non-null      object
#  6   reason5      2 non-null      object
#  7   reason6      0 non-null      float64
#  8   reason7      2 non-null      object
#  9   reason8      2 non-null      object
#  10  reason9      2 non-null      object
#  11  reason10     2 non-null      object
#  12  reason11     2 non-null      object
#  13  reason12     2 non-null      object
#  14  reason13     2 non-null      object
#  15  Unnamed: 15  0 non-null      float64
# dtypes: float64(2), int64(1), object(13)
# memory usage: 264.5+ KB

# %%
print(list(df.id))
# Out:
# [20, 23, 24, 32, 36, 39, 45, 47, 58, 60, 63, 64, 79, 90, 98, 107, 109, 120, 128, 129, 138, 140, 157, 168, 182, 186, 187, 188, 193, 194, 199, 202, 206, 216, 240, 244, 256, 257, 258, 263, 279, 285, 286, 289, 302, 307, 312, 319, 321, 339, 342, 350, 355, 358, 363, 365, 366, 367, 371, 373, 382, 383, 384, 389, 390, 392, 394, 412, 423, 428, 429, 435, 436, 438, 443, 449, 463, 471, 473, 474, 475, 493, 494, 496, 497, 498, 505, 512, 530, 534, 542, 547, 556, 559, 566, 591, 592, 594, 595, 597, 602, 603, 604, 605, 606, 615, 620, 646, 647, 649, 650, 651, 652, 656, 661, 662, 669, 670, 672, 673, 681, 682, 691, 695, 696, 709, 714, 715, 726, 729, 734, 778, 779, 784, 785, 786, 787, 788, 789, 790, 793, 794, 800, 805, 811, 819, 832, 852, 859, 862, 866, 889, 890, 891, 898, 909, 926, 927, 945, 947, 950, 951, 957, 961, 962, 963, 966, 969, 970, 972, 977, 978, 997, 1001, 1006, 1028, 1029, 1031, 1032, 1045, 1047, 1049, 1057, 1059, 1061, 1066, 1067, 1069, 1071, 1072, 1073, 1077, 1080, 1083, 1087, 1104, 1105, 110
# ...

# %%
print(df.id.unique())
# Out:
# [  20   23   24 ... 9120 9121 9128]

# %%
print(df.id.value_counts(ascending=True))
# Out:
# 20      1
# 6107    1
# 6102    1
# 6101    1
# 6090    1
#        ..
# 3361    1
# 3358    1
# 3356    1
# 3415    1
# 9128    1
# Name: id, Length: 2115, dtype: int64

# %%
df.drop(['reason6'], axis=1, inplace=True)

# %%
df.drop(['Unnamed: 15'], axis=1, inplace=True)

# %%
df['reason13'].unique()
# Out:
# array([nan,
#        "우장산힐스테이트'  '116동'  '504호' => 'LCG_MOUNTAIN'  'QT_ADDRESS'  'QT_ORDER'"],
#       dtype=object)

# %%
for i in range(len(df['reason13'])):
    if df['reason13'][i] == "우장산힐스테이트'  '116동'  '504호' => 'LCG_MOUNTAIN'  'QT_ADDRESS'  'QT_ORDER'":
        print(i)
# Out:
# 1725
# 1726

# %%
print(df.iloc[1725])
# Out:
# id                                                         7329
# error case                                               4번 10번
# reason1       연희동'  '예지원'  '202호' => 'LCP_COUNTY'  'PS_NAME'...
# reason2       16'  '럭키아파트'  '107호' => 'QT_ADDRESS'  'AF_BUIL...
# reason3                    OGG_HOTEL'  'QT_ADDRESS'  'QT_ORDER'
# reason4                 AF_BUILDING'  'AF_BUILDING'  'QT_ORDER'
# reason5       고척파크푸르지오'  '111동'  '605호' => 'AF_BUILDING'  'Q...
# reason7                 LCP_COUNTY'  'AF_BUILDING'  'QT_OTHERS'
# reason8                   QT_ADDRESS'  'LCP_COUNTY'  'QT_ORDER'
# reason9       동아불암아파트'  '104동'  '1504호' => 'AF_BUILDING'  'Q...
# reason10                    LCP_COUNTY'  'QT_ORDER'  'QT_ORDER'
# reason11                  LCP_COUNTY'  'LCP_COUNTY'  'QT_ORDER'
# reason12                  LCP_COUNTY'  'LCP_COUNTY'  'QT_ORDER'
# reason13      우장산힐스테이트'  '116동'  '504호' => 'LCG_MOUNTAIN'  '...
# Name: 1725, dtype: object

# %%
df.head()
# Out:
#    id error case  ... reason12 reason13
# 0  20         5번  ...      NaN      NaN
# 1  23         4번  ...      NaN      NaN
# 2  24         5번  ...      NaN      NaN
# 3  32         1번  ...      NaN      NaN
# 4  36         해결  ...      NaN      NaN
#
# [5 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2115 entries, 0 to 2114
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          2115 non-null   int64
#  1   error case  2115 non-null   object
#  2   reason1     1440 non-null   object
#  3   reason2     72 non-null     object
#  4   reason3     8 non-null      object
#  5   reason4     2 non-null      object
#  6   reason5     2 non-null      object
#  7   reason7     2 non-null      object
#  8   reason8     2 non-null      object
#  9   reason9     2 non-null      object
#  10  reason10    2 non-null      object
#  11  reason11    2 non-null      object
#  12  reason12    2 non-null      object
#  13  reason13    2 non-null      object
# dtypes: int64(1), object(13)
# memory usage: 231.5+ KB

# %%
df['error case'].unique()
# Out:
# array(['5번', '4번', '1번', '해결', '3번', '6번', '5번 10번', '잘못 체크', '4번 5번',
#        '2번', '10번', '9번', '4번 9번', '1번 4번', '4번 6번', '4번 11번', '4번 10번',
#        '12번', '이모지', '7번', '4번 8번', '8번', '1번 9번',
#        '이건 주소 찾아봐도 2개 나오고 그냥 도로명 주소부터 시작이라...', '7번 11번', '6번 5번',
#        '체크 잘못', '1번 5번', '11번', '3번 12번', '잡음', '1번 인데 \\n3)문자 인 케이스',
#        '뒤에 - 가 붙어서?', '1번 11번', "9번 '3수' => 'QT_ORDER'", '1번 10번',
#        '이건 좀 애매한데... 9번?', '1번 3번', '######################## 다시 확인',
#        '잘됨', '3번 5번', '5번 6번', '5번 9번', '4번 9번 10번', '6번 9번', '4번 5번 10번',
#        '애매하네', '태깅 짧음', '######### 코드 확인 필요', '4번 10번 11번', '3번 4번 10번',
#        '3번 4번', '5번10번', '태그 부족', '태깅 부족', '5번 9번 10번', '5번 10번 11번',
#        '########## 코드확인', '메시지가 없어서 확인 어려움', '전화번호를 인식 못해서 발생한 문제',
#        '5번 6번 10번', '이건  주소가 없음', '9번 10번', '이건 좀...', '이건 주소가 없음',
#        '태그가 너무 짧음', '주소가 너무 짧음', '3번 4번 5번'], dtype=object)

# %%
error_case = list(df['error case'].unique())
print(len(error_case))
error_case
# Out:
# 68
# ['5번',
#  '4번',
#  '1번',
#  '해결',
#  '3번',
#  '6번',
#  '5번 10번',
#  '잘못 체크',
#  '4번 5번',
#  '2번',
#  '10번',
#  '9번',
#  '4번 9번',
#  '1번 4번',
#  '4번 6번',
#  '4번 11번',
#  '4번 10번',
#  '12번',
#  '이모지',
#  '7번',
#  '4번 8번',
#  '8번',
#  '1번 9번',
#  '이건 주소 찾아봐도 2개 나오고 그냥 도로명 주소부터 시작이라...',
#  '7번 11번',
#  '6번 5번',
#  '체크 잘못',
#  '1번 5번',
#  '11번',
#  '3번 12번',
#  '잡음',
#  '1번 인데 \\n3)문자 인 케이스',
#  '뒤에 - 가 붙어서?',
#  '1번 11번',
#  "9번 '3수' => 'QT_ORDER'",
#  '1번 10번',
#  '이건 좀 애매한데... 9번?',
#  '1번 3번',
#  '######################## 다시 확인',
#  '잘됨',
#  '3번 5번',
#  '5번 6번',
#  '5번 9번',
#  '4번 9번 10번',
#  '6번 9번',
#  '4번 5번 10번',
#  '애매하네',
#  '태깅 짧음',
#  '######### 코드 확인 필요',
#  '4번 10번 11번',
#  '3번 4번 10번',
#  '3번 4번',
#  '5번10번',
#  '태그 부족',
#  '태깅 부족',
#  '5번 9번 10번',
#  '5번 10번 11번',
#  '########## 코드확인',
#  '메시지가 없어서 확인 어려움',
#  '전화번호를 인식 못해서 발생한 문제',
#  '5번 6번 10번',
#  '이건  주소가 없음',
#  '9번 10번',
#  '이건 좀...',
#  '이건 주소가 없음',
#  '태그가 너무 짧음',
#  '주소가 너무 짧음',
#  '3번 4번 5번']

# %%
for i in range(len(error_case)):
    globals()[f"case_{i}"] = df.loc[df['error case'] == error_case[i]]

# %% [markdown]
# # 5번

# %%
case_0
# Out:
#         id error case  ... reason12 reason13
# 0       20         5번  ...      NaN      NaN
# 2       24         5번  ...      NaN      NaN
# 16     109         5번  ...      NaN      NaN
# 28     193         5번  ...      NaN      NaN
# 29     194         5번  ...      NaN      NaN
# ...    ...        ...  ...      ...      ...
# 2076  8981         5번  ...      NaN      NaN
# 2088  9019         5번  ...      NaN      NaN
# 2089  9020         5번  ...      NaN      NaN
# 2090  9021         5번  ...      NaN      NaN
# 2101  9060         5번  ...      NaN      NaN
#
# [320 rows x 14 columns]

# %%
case_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320 entries, 0 to 2101
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          320 non-null    int64
#  1   error case  320 non-null    object
#  2   reason1     319 non-null    object
#  3   reason2     6 non-null      object
#  4   reason3     0 non-null      object
#  5   reason4     0 non-null      object
#  6   reason5     0 non-null      object
#  7   reason7     0 non-null      object
#  8   reason8     0 non-null      object
#  9   reason9     0 non-null      object
#  10  reason10    0 non-null      object
#  11  reason11    0 non-null      object
#  12  reason12    0 non-null      object
#  13  reason13    0 non-null      object
# dtypes: int64(1), object(13)
# memory usage: 37.5+ KB

# %%
case_0.drop(['reason3', 'reason4', 'reason5','reason7','reason8','reason9','reason10','reason11','reason12','reason13'], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
print(len(case_0.reason1.unique()))
case_0.reason1.unique()
# Out:
# 61
# array(["LCP_PROVINCE' 'AF_BUILDING'",
#        "LCP_COUNTY' 'QT_ADDRESS' 'OGG_FOOD'", "AF_ROAD' 'QT_ADDRESS'",
#        "AF_BUILDING' 'QT_ADDRESS'", "LCP_COUNTY' 'LCP_COUNTY'",
#        "LCP_COUNTY' 'AF_ROAD'", "QT_ADDRESS' 'LCP_COUNTY' 'QT_ORDER'",
#        "AF_BUILDING' 'QT_OTHERS'", "LCP_COUNTY' 'LCP_CITY'",
#        "LCP_PROVINCE' 'QT_ORDER'", "LCP_PROVINCE' 'QT_ADDRESS'",
#        "LCP_CITY' 'AF_ROAD' 'AF_BUILDING'", "AF_ROAD' 'LCP_COUNTY'",
#        "LCP_CITY' ''", "충남당진시' '송악읍' => 'OGG_POLITICS' 'LCP_COUNTY'", nan,
#        "경남창원시' '의창구' => 'CV_POSITION' 'LCP_COUNTY'",
#        "AF_ROAD' 'AF_ROAD'  10번 '경남' '김해시번화1로67번길' =>'AF_ROAD' 'AF_ROAD'",
#        "AF_BUILDING' 'LCP_COUNTY' 10번 '서울시' '관악구'  'AF_BUILDING' 'LCP_COUNTY'",
#        "LCP_CITY' 'AM_BIRD'", "LCP_COUNTY' 'QT_ADDRESS'",
#        "AF_BUILDING' 'AF_BUILDING'",
#        "일산시' '동구' => 'LCP_COUNTY' 'LCP_COUNTY'",
#        "LCP_COUNTY' 'AF_ROAD'  아 이게 좀 애매한데.....",
#        "AF_BUILDING' 'LCP_COUNTY'",
# ...

# %% [markdown]
# # 4번

# %%
case_1
# Out:
#         id error case  ... reason12 reason13
# 1       23         4번  ...      NaN      NaN
# 10      63         4번  ...      NaN      NaN
# 11      64         4번  ...      NaN      NaN
# 18     128         4번  ...      NaN      NaN
# 19     129         4번  ...      NaN      NaN
# ...    ...        ...  ...      ...      ...
# 2106  9073         4번  ...      NaN      NaN
# 2107  9075         4번  ...      NaN      NaN
# 2108  9090         4번  ...      NaN      NaN
# 2112  9120         4번  ...      NaN      NaN
# 2113  9121         4번  ...      NaN      NaN
#
# [581 rows x 14 columns]

# %%
case_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 581 entries, 1 to 2113
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          581 non-null    int64
#  1   error case  581 non-null    object
#  2   reason1     581 non-null    object
#  3   reason2     5 non-null      object
#  4   reason3     0 non-null      object
#  5   reason4     0 non-null      object
#  6   reason5     0 non-null      object
#  7   reason7     0 non-null      object
#  8   reason8     0 non-null      object
#  9   reason9     0 non-null      object
#  10  reason10    0 non-null      object
#  11  reason11    0 non-null      object
#  12  reason12    0 non-null      object
#  13  reason13    0 non-null      object
# dtypes: int64(1), object(13)
# memory usage: 68.1+ KB

# %%
case_1.drop(['reason3', 'reason4', 'reason5','reason7','reason8','reason9','reason10','reason11','reason12','reason13'], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
print(len(case_1.reason1.unique()))
case_1.reason1.unique()
# Out:
# 258
# array(["QT_ADDRESS' 'OGG_ECONOMY' 'QT_ADDRESS'",
#        "LC_OTHERS' 'QT_ADDRESS' 'QT_ADDRESS'",
#        "AF_BUILDING' 'AF_BUILDING' 'QT_ORDER'",
#        "LCP_COUNTY' 'AFW_OTHER_PRODUCTS' 'QT_ADDRESS'",
#        "QT_ADDRESS' 'LCP_COUNTY' 'QT_ORDER'",
#        "AF_CULTURAL_ASSET' 'QT_ADDRESS' 'QT_ADDRESS'",
#        "QT_ADDRESS' 'QT_MAN_COUNT' 'QT_ADDRESS'",
#        "AF_ROAD' 'AF_BUILDING' 'QT_ORDER'",
#        "LCP_COUNTY' 'QT_PHONE' 'QT_ADDRESS'",
#        "LCP_COUNTY' 'AF_ROAD' 'QT_ORDER'",
#        "OGG_ECONOMY' 'QT_ORDER' 'QT_ORDER'",
#        "QT_ADDRESS' 'AF_ROAD' 'QT_ORDER'", "QT_ADDRESS' '' 'QT_ORDER'",
#        "QT_ORDER' 'QT_ORDER' 'QT_ORDER'",
#        "AF_ROAD' 'AF_ROAD' 'QT_ADDRESS'",
#        "LCG_ISLAND' 'AF_BUILDING' 'QT_ADDRESS'",
#        "LCP_COUNTY' 'QT_ORDER' 'QT_ORDER'", " 'QT_ADDRESS' 'QT_ADDRESS'",
#        "LCP_COUNTY' 'AF_ROAD' 'AF_BUILDING'",
#        "LCP_COUNTY' 'LCP_COUNTY' 'AF_ROAD'",
#        "LCP_CITY' 'AF_BUILDING' 'QT_ADDRESS'",
# ...

# %%
case_1
# Out:
#         id  ...                                 reason2
# 1       23  ...                                     NaN
# 10      63  ...                                     NaN
# 11      64  ...                                     NaN
# 18     128  ...                                     NaN
# 19     129  ...                                     NaN
# ...    ...  ...                                     ...
# 2106  9073  ...                                     NaN
# 2107  9075  ...                                     NaN
# 2108  9090  ...  AF_BUILDING'  'QT_ADDRESS'  'QT_ORDER'
# 2112  9120  ...                                     NaN
# 2113  9121  ...                                     NaN
#
# [581 rows x 4 columns]

# %% [markdown]
# # 1번

# %%
case_2
# Out:
#         id error case reason1 reason2  ... reason10 reason11 reason12 reason13
# 3       32         1번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 5       39         1번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 21     140         1번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 22     157         1번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 27     188         1번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# ...    ...        ...     ...     ...  ...      ...      ...      ...      ...
# 1975  8611         1번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 1977  8621         1번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 1982  8636         1번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 1986  8659         1번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 1987  8661         1번     NaN     NaN  ...      NaN      NaN      NaN      NaN
#
# [213 rows x 14 columns]

# %% [markdown]
# # 해결

# %%
case_3
# Out:
#         id error case reason1 reason2  ... reason10 reason11 reason12 reason13
# 4       36         해결     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 7       47         해결     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 9       60         해결     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 42     286         해결     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 114    661         해결     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 130    734         해결     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 142    800         해결     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 149    862         해결     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 163    961         해결     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 233   1255         해결     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 258   1392         해결     NaN     NaN  ...      NaN      NaN      NaN      NaN
# ...

# %% [markdown]
# # 3번

# %%
case_4
# Out:
#         id error case reason1 reason2  ... reason10 reason11 reason12 reason13
# 6       45         3번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 32     206         3번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 34     240         3번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 58     371         3번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 74     443         3번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# ...    ...        ...     ...     ...  ...      ...      ...      ...      ...
# 2045  8883         3번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 2046  8884         3번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 2051  8901         3번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 2081  8994         3번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 2094  9038         3번     NaN     NaN  ...      NaN      NaN      NaN      NaN
#
# [172 rows x 14 columns]

# %% [markdown]
# # 6반

# %%
case_5
# Out:
#         id error case reason1 reason2  ... reason10 reason11 reason12 reason13
# 8       58         6번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 52     355         6번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 71     435         6번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 72     436         6번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 150    866         6번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 500   2506         6번     강윈도     NaN  ...      NaN      NaN      NaN      NaN
# 587   2890         6번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 615   2988         6번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 683   3301         6번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 815   3853         6번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 889   4164         6번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# ...

# %% [markdown]
# # 5번 10번

# %%
case_6
# Out:
#         id error case  ... reason12 reason13
# 12      79     5번 10번  ...      NaN      NaN
# 162    957     5번 10번  ...      NaN      NaN
# 215   1178     5번 10번  ...      NaN      NaN
# 245   1335     5번 10번  ...      NaN      NaN
# 267   1436     5번 10번  ...      NaN      NaN
# ...    ...        ...  ...      ...      ...
# 1950  8516     5번 10번  ...      NaN      NaN
# 2061  8962     5번 10번  ...      NaN      NaN
# 2095  9039     5번 10번  ...      NaN      NaN
# 2096  9040     5번 10번  ...      NaN      NaN
# 2097  9042     5번 10번  ...      NaN      NaN
#
# [83 rows x 14 columns]

# %% [markdown]
# # 잘못 체크

# %%
case_7
# Out:
#         id error case reason1 reason2  ... reason10 reason11 reason12 reason13
# 13      90      잘못 체크     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 134    785      잘못 체크     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 135    786      잘못 체크     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 165    963      잘못 체크     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 218   1183      잘못 체크     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 299   1604      잘못 체크     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 374   1948      잘못 체크     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 508   2547      잘못 체크     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 594   2921      잘못 체크     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 634   3107      잘못 체크     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 635   3108      잘못 체크     NaN     NaN  ...      NaN      NaN      NaN      NaN
# ...

# %% [markdown]
# # 4번 5번

# %%
case_8
# Out:
#         id error case  ... reason12 reason13
# 14      98      4번 5번  ...      NaN      NaN
# 15     107      4번 5번  ...      NaN      NaN
# 829   3907      4번 5번  ...      NaN      NaN
# 891   4167      4번 5번  ...      NaN      NaN
# 1026  4650      4번 5번  ...      NaN      NaN
# 1027  4651      4번 5번  ...      NaN      NaN
# 1654  6977      4번 5번  ...      NaN      NaN
# 1656  6979      4번 5번  ...      NaN      NaN
#
# [8 rows x 14 columns]

# %% [markdown]
# # 2번

# %%
case_9
# Out:
#         id error case reason1 reason2  ... reason10 reason11 reason12 reason13
# 17     120         2번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 44     302         2번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 77     471         2번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 172    997         2번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 191   1077         2번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 236   1268         2번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 238   1291         2번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 248   1351         2번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 249   1354         2번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 279   1487         2번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 370   1941         2번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# ...

# %% [markdown]
# # 10번

# %%
case_10
# Out:
#         id error case  ... reason12 reason13
# 20     138        10번  ...      NaN      NaN
# 33     216        10번  ...      NaN      NaN
# 43     289        10번  ...      NaN      NaN
# 46     312        10번  ...      NaN      NaN
# 64     390        10번  ...      NaN      NaN
# ...    ...        ...  ...      ...      ...
# 2020  8807        10번  ...      NaN      NaN
# 2100  9050        10번  ...      NaN      NaN
# 2102  9061        10번  ...      NaN      NaN
# 2103  9062        10번  ...      NaN      NaN
# 2111  9112        10번  ...      NaN      NaN
#
# [154 rows x 14 columns]

# %% [markdown]
# # 9번

# %%
case_11
# Out:
#         id error case  ... reason12 reason13
# 24     182         9번  ...      NaN      NaN
# 62     384         9번  ...      NaN      NaN
# 205   1147         9번  ...      NaN      NaN
# 209   1158         9번  ...      NaN      NaN
# 255   1381         9번  ...      NaN      NaN
# ...    ...        ...  ...      ...      ...
# 1885  8155         9번  ...      NaN      NaN
# 1932  8421         9번  ...      NaN      NaN
# 1976  8616         9번  ...      NaN      NaN
# 2082  8999         9번  ...      NaN      NaN
# 2114  9128         9번  ...      NaN      NaN
#
# [111 rows x 14 columns]

# %% [markdown]
# # 4번 9번

# %%
case_12
# Out:
#         id error case  ... reason12 reason13
# 40     279      4번 9번  ...      NaN      NaN
# 1043  4728      4번 9번  ...      NaN      NaN
# 1190  5286      4번 9번  ...      NaN      NaN
# 1191  5287      4번 9번  ...      NaN      NaN
# 1433  6177      4번 9번  ...      NaN      NaN
#
# [5 rows x 14 columns]

# %% [markdown]
# # 1번 4번

# %%
case_13
# Out:
#         id error case  ... reason12 reason13
# 41     285      1번 4번  ...      NaN      NaN
# 197   1107      1번 4번  ...      NaN      NaN
# 228   1222      1번 4번  ...      NaN      NaN
# 293   1577      1번 4번  ...      NaN      NaN
# 294   1578      1번 4번  ...      NaN      NaN
# 449   2307      1번 4번  ...      NaN      NaN
# 1755  7427      1번 4번  ...      NaN      NaN
# 1756  7428      1번 4번  ...      NaN      NaN
# 2104  9067      1번 4번  ...      NaN      NaN
#
# [9 rows x 14 columns]

# %% [markdown]
# # 4번 6번

# %%
case_14
# Out:
#         id error case  ... reason12 reason13
# 53     358      4번 6번  ...      NaN      NaN
# 571   2836      4번 6번  ...      NaN      NaN
# 1815  7707      4번 6번  ...      NaN      NaN
#
# [3 rows x 14 columns]

# %% [markdown]
# # 4번 11번

# %%
case_15
# Out:
#        id error case  ... reason12 reason13
# 55    365     4번 11번  ...      NaN      NaN
# 56    366     4번 11번  ...      NaN      NaN
# 57    367     4번 11번  ...      NaN      NaN
# 193  1083     4번 11번  ...      NaN      NaN
# 240  1295     4번 11번  ...      NaN      NaN
#
# [5 rows x 14 columns]

# %% [markdown]
# # 4번 10번

# %%
case_16
# Out:
#         id error case  ... reason12 reason13
# 65     392     4번 10번  ...      NaN      NaN
# 94     566     4번 10번  ...      NaN      NaN
# 146    832     4번 10번  ...      NaN      NaN
# 169    972     4번 10번  ...      NaN      NaN
# 170    977     4번 10번  ...      NaN      NaN
# ...    ...        ...  ...      ...      ...
# 2008  8782     4번 10번  ...      NaN      NaN
# 2030  8859     4번 10번  ...      NaN      NaN
# 2050  8897     4번 10번  ...      NaN      NaN
# 2056  8948     4번 10번  ...      NaN      NaN
# 2058  8955     4번 10번  ...      NaN      NaN
#
# [119 rows x 14 columns]

# %% [markdown]
# # 12번

# %%
case_17
# Out:
#         id error case reason1 reason2  ... reason10 reason11 reason12 reason13
# 83     496        12번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 84     497        12번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 124    696        12번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 148    859        12번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 302   1612        12번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 412   2151        12번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 466   2352        12번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 584   2882        12번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 679   3282        12번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 782   3701        12번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 813   3841        12번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# ...

# %% [markdown]
# # 이모지

# %%
case_18
# Out:
#      id error case reason1 reason2  ... reason10 reason11 reason12 reason13
# 90  542        이모지     NaN     NaN  ...      NaN      NaN      NaN      NaN
#
# [1 rows x 14 columns]

# %% [markdown]
# # 7번

# %%
case_19
# Out:
#         id error case reason1 reason2  ... reason10 reason11 reason12 reason13
# 127    715         7번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 194   1087         7번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 459   2329         7번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 1629  6858         7번     NaN     NaN  ...      NaN      NaN      NaN      NaN
#
# [4 rows x 14 columns]

# %% [markdown]
# # 4번 8번

# %%
case_20
# Out:
#         id error case  ... reason12 reason13
# 159    947      4번 8번  ...      NaN      NaN
# 1188  5276      4번 8번  ...      NaN      NaN
#
# [2 rows x 14 columns]

# %% [markdown]
# # 8번

# %%
case_21
# Out:
#         id error case reason1 reason2  ... reason10 reason11 reason12 reason13
# 184   1061         8번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 371   1944         8번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 643   3145         8번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 707   3413         8번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 807   3797         8번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 820   3872         8번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 821   3873         8번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 958   4434         8번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 959   4435         8번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 1048  4743         8번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 1124  5016         8번     NaN     NaN  ...      NaN      NaN      NaN      NaN
# ...

# %% [markdown]
# # 1번 9번

# %%
case_22
# Out:
#         id error case  ... reason12 reason13
# 199   1113      1번 9번  ...      NaN      NaN
# 544   2734      1번 9번  ...      NaN      NaN
# 593   2919      1번 9번  ...      NaN      NaN
# 675   3259      1번 9번  ...      NaN      NaN
# 789   3732      1번 9번  ...      NaN      NaN
# 800   3778      1번 9번  ...      NaN      NaN
# 1314  5744      1번 9번  ...      NaN      NaN
# 1476  6336      1번 9번  ...      NaN      NaN
# 1503  6450      1번 9번  ...      NaN      NaN
#
# [9 rows x 14 columns]
