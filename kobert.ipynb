# %% [markdown]
# <a href="https://colab.research.google.com/github/ssunggun2/Portfolio/blob/main/kobert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import json
from pandas.io.json import json_normalize

import re
from tqdm.notebook import tqdm

import warnings
warnings.filterwarnings('ignore')

# %%
with open('/content/drive/MyDrive/gas_dacon/data/Training/신문기사_train_original/train_original.json') as f:
    train = json.load(f)

# %%
# # test = pd.read_json('/content/drive/MyDrive/gas_dacon/data/Validation/신문기사_valid_original/vaild_original.json', lines=True)
# print("train set :", train.shape)
# # print("test set :", test.shape)

# %%
'''
df = pd.DataFrame(train['documents'])
df.head()
df.text[0]
df.text[1]
df.text[1][2]
sent2=[]
for article in df.text:
    sentence=[]
    for row in article:
        if row:
            # print(row[0]['sentence'])
            # print(row)
            tmp=row[0]['sentence']
            sentence.append(tmp)
        else:
            pass
    # print(sentence)
    sent2.append(sentence)        
    
    # print('\n')

    
sent2[:2]
df2 = pd.DataFrame()
df2['sentence']=sent2
df2['abstractive']=df.abstractive
df2.head(15)
df2.sentence
df2['text']='None'
res=[]
for i in range(len(df2.sentence)):
    tmp=' '.join(df2.sentence[i])
    df2.text[i]=tmp
'''


df2['abs']='None'
res=[]
for i in range(len(df2.abstractive)):
    tmp=' '.join(df2.abstractive[i])
    df2.abs[i]=tmp

    
df2.head()
df2.to_csv('/content/drive/MyDrive/gas_dacon/data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-07ccfffa08d5> in <module>()
#      34     df2.text[i]=tmp
#      35 '''
# ---> 36 df2['abs']='None'
#      37 res=[]
#      38 for i in range(len(df2.abstractive)):
#
# NameError: name 'df2' is not defined

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 3.1 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 59 kB 7.6 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 42.9 MB/s
# ...
#      |████████████████████████████████| 895 kB 52.4 MB/s
# ...
#      |████████████████████████████████| 596 kB 41.7 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from transformers import BertTokenizerFast, BertModel

tokenizer_bert = BertTokenizerFast.from_pretrained("kykim/bert-kor-base")
# Out:
# Downloading:   0%|          | 0.00/336k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/80.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/725 [00:00<?, ?B/s]

# %%
enc = tokenizer_bert.encode('i love you'.split())
dec = tokenizer_bert.decode(enc)
print(enc)
print(dec)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-38b6ca8db5c7> in <module>()
# ----> 1 enc = tokenizer_bert.encode('i love you'.split())
#       2 dec = tokenizer_bert.decode(enc)
#       3 print(enc)
#       4 print(dec)
#
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py in encode(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, return_tensors, **kwargs)
#    2174             stride=stride,
#    2175             return_tensors=return_tensors,
# -> 2176             **kwargs,
#    2177         )
#    2178
#
# ...

# %%
 
model_bert = BertModel.from_pretrained("kykim/bert-kor-base")

# %%
# !git clone https://github.com/kiyoungkim1/LMkor
# !pip3 install -q transformers

from LMkor.examples.bertshared_summarization import Summarize
summarize = Summarize('kykim/bertshared-kor-base')
# Out:
# Cloning into 'LMkor'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 95 (delta 41), reused 51 (delta 17), pack-reused 0
# Unpacking objects: 100% (95/95), done.
# Downloading:   0%|          | 0.00/336k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/80.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.14k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/562M [00:00<?, ?B/s]

# %%
df2=pd.read_csv('/content/drive/MyDrive/gas_dacon/data.csv')

# %%
df2['sum']='None'

# %%
summarize(df2.text[0])
# Out:
# 전라남도가 쌀 과잉문제를 해결하기 위해 올해부터 시행하는 쌀 생산조정제는 논에 벼 대신 사료작물이나 콩 등 다른 작물을 심으면 벼와의 일정 소득차를 보전해주는 제도로 ha당면적은 전국 5만ha의 약 21 % 인 1만 698ha에 기초시행지 읍면동사무소에 신청해야 한다. 논 타작물 지원사업 추진협의회 를 구성하여 지역 특성에 맞는 작목 선정 및 사업 심의 등을 본격 추진할 방침이다 전남도는 이와 관련된 기관과 농가 등이 참여하는 논타작물이 지원

# %%
df2.text.size
# Out:
# 271093

# %%
df2['text_len']   = df2['text'].str.len()

# %%
df2.head(15)
# Out:
#                                              sentence  ... text_len
# 0   [ha당 조사료 400만원…작물별 차등 지원, 이성훈 sinawi@hanmail.n...  ...      785
# 1   [8억 투입, 고소천사벽화·자산마을에 색채 입혀, 이성훈 sinawi@hanmail...  ...      478
# 2   [전남드래곤즈 해맞이 다짐…선수 영입 활발, 이성훈 sinawi@hanmail.ne...  ...      397
# 3   [11~24일, 매실·감·참다래 등 지역특화작목, 이성훈 sinawi@hanmail...  ...      560
# 4   [홍콩 크루즈선사‘아쿠아리우스’ 4, 6월 여수항 입항, 이성훈 sinawi@han...  ...      570
# 5   [30인 미만 중소기업 등 사업주에 월 13만원 지급, 이성훈 sinawi@hanm...  ...      842
# 6   [일방적인 시내버스 감차, 시민들 분노, 김영신 기자 yskim0966@naver....  ...      619
# 7   [교육지원청 Wee센터, 겨울방학 카운슬링 운영, 김영신 기자 yskim0966@n...  ...      521
# 8   [서양화가 강홍순 전, 정인수 화가‘通통通통한 산수화’전, 김영신 기자 yskim0...  ...     1151
# 9   [4개 과정, 38과목 선발…반려동물 관리사 신설, 이성훈 sinawi@hanmai...  ...      665
# 10  [전년도 대비 79명 늘어 1019명, 행정수요 대처, 이성훈 sinawi@hanm...  ...      734
# 11  [수도권 소재 2년제 이상 대학교 신입생·재학생·대학원생…부모가 1년 이상 광양거주...  ...      637
# 12  [신년 기자간담회…개발 자제, 시민 행복 정책 초점, 이성훈 sinawi@hanma...  ...     1157
# ...

# %%
# 이건 안되네
# for i in range(len(df2.text)):
#     sum=summarize(df2.text[i])
#     print(sum)
# Out:
# 전라남도가 쌀 과잉문제를 해결하기 위해 올해부터 시행하는 쌀 생산조정제는 논에 벼 대신 사료작물이나 콩 등 다른 작물을 심으면 벼와의 일정 소득차를 보전해주는 제도로 ha당면적은 전국 5만ha의 약 21 % 인 1만 698ha에 기초시행지 읍면동사무소에 신청해야 한다. 논 타작물 지원사업 추진협의회 를 구성하여 지역 특성에 맞는 작목 선정 및 사업 심의 등을 본격 추진할 방침이다 전남도는 이와 관련된 기관과 농가 등이 참여하는 논타작물이 지원
# None
# 여수시는 원도심 일대에서 추진된 컬러빌리지 사업을 통해 고소천사벽화마을과 자산마을이 색채를 입히며 색채와 빛을 입히면서 이국적인 분위기를 자아내고 있다. 색채는 지난해 말 마무리하며 주민들이 주민들의 적극적인 관심과 참여가 만들어낸 값진 성과물이라고 밝혔다 공모시설인
# None
# 전남드래곤즈는 지난 4일 구봉산 해맞이 행사를 통해 새해 각오를 다졌다. 유상철 감독은 k리그 클래식 5위 이내 진입, fa컵 우승 등 acl 진출권 획득을 목표로 최선을 다하자 고 선수들도 추가 영입했다고 밝혔다.
# None
# 광양시는 농업인들의 경쟁력을 높이고, 소득안정을 위해 오는 11일부터 24일까지 농업인 1050명을 대상으로 저비용 생산과 고품질 재배기술을 중점적으로 다룬다. 광양시 농업기술센터 홈페이지에서 확인할 수 있고, 자세한 교육 일정은 광양농업기술센터에서 확인 할 수 있다 농업인들은 기술보급과 기술지원팀 ( 797 - 3323
# None
# 지난해 상반기부터 타이완에서 크루즈관광객 4000여명이 올해 두 차례에 걸쳐 여수에 입항한다. 크루즈 관광객들은 이번 스타크루즈 관광객들을 통해 기업포상단체를 위한 대규모 인프라가 갖춰지고, 도보 20분 이내로 주요 관광지가 밀집해 개별 관광객에 최적화된 여수크루스항의 장점을 알려나가겠다고 밝혔다 블루완 크루즈
# None
# ...

# %%
df2
